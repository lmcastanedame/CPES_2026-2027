# %% [markdown]
# # Conditions et boucles en Python
#
# Séance intensive de 3 heures pour débutants.
#
# > Note enseignant : ce notebook est conçu pour alterner rapidement entre discussion, prédiction, codage et correction collective.

# %% [markdown]
# ## Vue d'ensemble du timing
#
# - Introduction et échauffement : 10 à 15 min
# - Décider avec `if`, `elif`, `else` : environ 40 min
# - Répéter avec `for` : environ 35 min
# - Répéter avec `while` : environ 30 min
# - Défi guidé combiné : environ 25 min
# - Mini-projet final : 30 à 40 min
# - Récapitulatif : 5 à 10 min

# %% [markdown]
# ## Objectifs de la séance
#
# À la fin de la séance, vous devriez pouvoir :
#
# - écrire une condition simple avec `if` ;
# - choisir entre `if`, `elif` et `else` ;
# - combiner des tests avec `and`, `or` et `not` ;
# - parcourir une liste avec une boucle `for` ;
# - répéter une action tant qu'une condition est vraie avec `while` ;
# - accumuler un total, compter des éléments ou suivre un score ;
# - repérer quelques erreurs classiques dans des conditions et des boucles.

# %% [markdown]
# ## Échauffement : prédire avant d'exécuter
#
# Avant de lancer les cellules, lisez le code et notez ce que vous pensez voir s'afficher.
#
# > Note enseignant : demander aux étudiants de répondre individuellement pendant une minute, puis comparer à deux.

# %%
age = 17

if age >= 18:
    print("Accès autorisé")
else:
    print("Accès refusé")

# %%
score = 12
bonus = 3

print(score + bonus >= 15)

# %% [markdown]
# ### Mini-correction rapide
#
# La cellule suivante contient une erreur. Essayez de la repérer avant de l'exécuter.

# %%
temperature = 28

if temperature > 25
    print("Il fait chaud")

# %% [markdown]
# # 1. Prendre des décisions avec Python

# %% [markdown]
# Un programme devient plus intéressant quand il peut choisir quoi faire selon une situation.
#
# Pour cela, Python utilise des expressions booléennes : des expressions qui valent soit `True`, soit `False`.

# %%
age = 20
print(age >= 18)
print(age < 18)

# %% [markdown]
# ## Comparer des valeurs
#
# Les opérateurs les plus courants sont :
#
# - `==` : égal à
# - `!=` : différent de
# - `<` : inférieur à
# - `<=` : inférieur ou égal à
# - `>` : supérieur à
# - `>=` : supérieur ou égal à
#
# Attention : `=` sert à donner une valeur à une variable. Pour tester une égalité, on utilise `==`.

# %%
mot_de_passe = "python"

print(mot_de_passe == "python")
print(mot_de_passe != "azerty")

# %% [markdown]
# ## Combiner plusieurs tests
#
# - `and` : les deux conditions doivent être vraies.
# - `or` : au moins une condition doit être vraie.
# - `not` : inverse une condition.

# %%
age = 19
a_reservation = True

print(age >= 18 and a_reservation)
print(age < 18 or a_reservation)
print(not a_reservation)

# %% [markdown]
# ## `if` : exécuter seulement si le test est vrai
#
# Le bloc indenté sous `if` ne s'exécute que si la condition vaut `True`.

# %%
temperature = 31

if temperature >= 30:
    print("Alerte chaleur")

print("Fin du contrôle")

# %% [markdown]
# ## `if` / `else` : choisir entre deux chemins

# %%
age = 15

if age >= 18:
    print("Tarif adulte")
else:
    print("Tarif réduit")

# %% [markdown]
# ## `if` / `elif` / `else` : choisir parmi plusieurs cas
#
# Python teste les conditions dans l'ordre. Dès qu'une condition est vraie, le bloc correspondant est exécuté.

# %%
note = 14

if note >= 16:
    print("Très bien")
elif note >= 10:
    print("Validé")
else:
    print("À retravailler")

# %% [markdown]
# ## Activité : prédire l'affichage
#
# Sans exécuter la cellule, dites ce qui va s'afficher. Expliquez pourquoi.

# %%
montant = 42
client_fidele = False

if montant >= 50 or client_fidele:
    print("Livraison gratuite")
else:
    print("Livraison payante")

# %% [markdown]
# ## Activité : déboguer
#
# Le code suivant devrait afficher `Connexion réussie` si le mot de passe est correct. Corrigez-le.

# %%
mot_de_passe = "python123"

if mot_de_passe = "python123":
    print("Connexion réussie")
else:
    print("Mot de passe incorrect")

# %% [markdown]
# ## Exercice 1 — 5 min
#
# **Objectif :** écrire une condition simple.
#
# Écrivez un programme qui demande l'âge d'une personne.
#
# - Si la personne a 18 ans ou plus, affichez `Vous pouvez voter`.
# - Sinon, affichez `Vous ne pouvez pas encore voter`.

# %% [markdown]
# ## Exercice 2 — 7 min
#
# **Objectif :** utiliser `if`, `elif` et `else`.
#
# Écrivez un programme qui demande une température en degrés Celsius.
#
# - En dessous de 0 : affichez `Risque de gel`.
# - De 0 à 25 inclus : affichez `Température normale`.
# - Au-dessus de 25 : affichez `Il fait chaud`.

# %% [markdown]
# ## Exercice 3 — 10 min
#
# **Objectif :** combiner plusieurs conditions.
#
# Un cinéma propose un tarif réduit si la personne a moins de 18 ans ou plus de 65 ans. Le tarif normal est appliqué dans les autres cas.
#
# Demandez l'âge, puis affichez le tarif :
#
# - `Tarif réduit` ;
# - ou `Tarif normal`.

# %% [markdown]
# ## Exercice 4 — 12 min
#
# **Objectif :** écrire une solution un peu plus ouverte.
#
# Un site de livraison calcule des frais selon le montant du panier et la distance.
#
# Règles proposées :
#
# - si le panier vaut au moins 50 euros, la livraison est gratuite ;
# - sinon, si la distance est inférieure ou égale à 5 km, la livraison coûte 3 euros ;
# - sinon, elle coûte 6 euros.
#
# Demandez le montant du panier et la distance, puis affichez les frais de livraison.
#
# > Note enseignant : accepter plusieurs organisations du code si les règles sont respectées.

# %% [markdown]
# # 2. Répéter des actions avec `for`

# %% [markdown]
# Quand on connaît à l'avance les éléments à traiter, une boucle `for` est souvent le bon outil.
#
# On peut parcourir une liste, une chaîne de caractères ou une suite de nombres créée avec `range()`.

# %%
notes = [12, 15, 9, 18]

for note in notes:
    print("Note lue :", note)

# %% [markdown]
# ## Utiliser `range()`
#
# `range(5)` produit les nombres de 0 à 4.
#
# `range(1, 6)` produit les nombres de 1 à 5.

# %%
for numero in range(1, 6):
    print("Passage", numero)

# %% [markdown]
# ## Accumuler un total
#
# Une boucle peut construire progressivement un résultat.

# %%
prix = [8, 12, 5, 20]
total = 0

for prix_article in prix:
    total = total + prix_article

print("Total :", total, "euros")

# %% [markdown]
# ## Activité : prédire l'affichage
#
# Que va afficher cette cellule ? Combien de lignes seront affichées ?

# %%
temperatures = [18, 27, 31, 22]
compteur = 0

for temperature in temperatures:
    if temperature >= 25:
        compteur = compteur + 1

print(compteur)

# %% [markdown]
# ## Activité : déboguer
#
# Le code suivant devrait calculer le total du panier. Il contient deux problèmes. Corrigez-les.

# %%
panier = [4, 7, 3]
total = 0

for prix in panier
total = total + prix

print(total)

# %% [markdown]
# ## Exercice 5 — 8 min
#
# **Objectif :** parcourir une liste.
#
# On dispose d'une liste de prénoms.
#
# Affichez une phrase de bienvenue pour chaque personne.
#
# Exemple attendu : `Bonjour Lina`.

# %%
prenoms = ["Lina", "Nora", "Adam", "Yanis"]

# %% [markdown]
# ## Exercice 6 — 10 min
#
# **Objectif :** compter des valeurs qui respectent une condition.
#
# Dans la liste suivante, comptez combien de notes sont supérieures ou égales à 10.
#
# Affichez ensuite : `Nombre de notes validées : ...`.

# %%
notes = [8, 12, 15, 6, 10, 19, 9]

# %% [markdown]
# ## Exercice 7 — 12 min
#
# **Objectif :** filtrer et accumuler.
#
# Un panier contient des prix. On veut calculer seulement le total des articles qui coûtent au moins 10 euros.
#
# Affichez le total obtenu.

# %%
prix = [4, 12, 9, 25, 3, 16]

# %% [markdown]
# ## Exercice 8 — 12 min
#
# **Objectif :** combiner `for`, `if` et un calcul.
#
# On dispose de températures relevées pendant une semaine.
#
# Écrivez un programme qui :
#
# - affiche chaque température ;
# - affiche `Alerte` à côté des températures supérieures ou égales à 30 ;
# - compte le nombre de jours en alerte ;
# - affiche ce nombre à la fin.

# %%
temperatures = [22, 28, 31, 35, 29, 24, 30]

# %% [markdown]
# # 3. Répéter jusqu'à ce qu'une situation arrive avec `while`

# %% [markdown]
# `for` est pratique quand on connaît la collection à parcourir.
#
# `while` est pratique quand on veut répéter tant qu'une condition reste vraie, surtout quand on ne sait pas à l'avance combien de répétitions seront nécessaires.

# %%
tentatives = 0

while tentatives < 3:
    print("Tentative", tentatives + 1)
    tentatives = tentatives + 1

print("Fin")

# %% [markdown]
# ## Éviter les boucles infinies
#
# Dans une boucle `while`, il faut vérifier que la condition pourra devenir fausse.
#
# Sinon, le programme peut tourner sans fin.

# %% [markdown]
# ## Activité : déboguer une boucle infinie
#
# La cellule suivante est volontairement dangereuse : ne l'exécutez pas avant d'avoir trouvé le problème.
#
# Que faut-il ajouter ou modifier ?

# %%
compteur = 1

while compteur <= 5:
    print(compteur)

# %% [markdown]
# ## Demander jusqu'à obtenir une réponse attendue

# %%
choix = ""

while choix != "oui":
    choix = input("Tapez oui pour continuer : ")

print("Merci")

# %% [markdown]
# ## `break` : sortir plus tôt d'une boucle
#
# `break` peut servir à interrompre une boucle quand un événement arrive.
#
# On l'utilise avec modération : souvent, une bonne condition dans `while` suffit.

# %%
while True:
    reponse = input("Écrivez stop pour arrêter : ")
    if reponse == "stop":
        break

print("Boucle terminée")

# %% [markdown]
# ## Exercice 9 — 10 min
#
# **Objectif :** répéter tant qu'une réponse n'est pas correcte.
#
# Demandez un mot de passe avec `input()`.
#
# Tant que le mot de passe n'est pas `python`, redemandez-le.
#
# Quand le mot de passe est correct, affichez `Bienvenue`.

# %% [markdown]
# ## Exercice 10 — 10 min
#
# **Objectif :** suivre un compteur dans une boucle `while`.
#
# Écrivez un programme qui affiche les nombres de 10 à 1, puis affiche `Décollage`.
#
# > Note enseignant : cet exercice sert surtout à vérifier la mise à jour de l'état de boucle.

# %% [markdown]
# ## Exercice 11 — 12 min
#
# **Objectif :** gérer un nombre de répétitions inconnu.
#
# Demandez des nombres à l'utilisateur.
#
# - Tant que l'utilisateur ne tape pas `stop`, continuez.
# - À chaque nombre saisi, ajoutez-le à un total.
# - À la fin, affichez le total.
#
# Conseil : gardez d'abord la saisie sous forme de texte, puis convertissez avec `int()` seulement si la valeur n'est pas `stop`.

# %% [markdown]
# # 4. Combiner conditions et boucles

# %% [markdown]
# Nous allons construire progressivement un petit programme de menu.
#
# Le programme doit :
#
# - afficher un menu ;
# - demander un choix ;
# - modifier un total ;
# - continuer jusqu'à ce que l'utilisateur décide de quitter.

# %% [markdown]
# ## Défi guidé, étape 1 — 6 min
#
# **Objectif :** afficher un menu et lire un choix.
#
# Affichez le menu suivant, puis demandez un choix avec `input()` :
#
# - `1 - Ajouter 5 euros`
# - `2 - Ajouter 10 euros`
# - `3 - Afficher le total`
# - `q - Quitter`
#
# Pour l'instant, affichez seulement le choix saisi.

# %% [markdown]
# ## Défi guidé, étape 2 — 7 min
#
# **Objectif :** réagir au choix avec `if`, `elif`, `else`.
#
# Reprenez le menu. Selon le choix :
#
# - `1` affiche `Ajout de 5 euros` ;
# - `2` affiche `Ajout de 10 euros` ;
# - `3` affiche `Affichage du total` ;
# - tout autre choix affiche `Choix inconnu`.

# %% [markdown]
# ## Défi guidé, étape 3 — 8 min
#
# **Objectif :** ajouter une boucle `while`.
#
# Le menu doit maintenant se répéter jusqu'à ce que l'utilisateur tape `q`.

# %% [markdown]
# ## Défi guidé, étape 4 — 8 min
#
# **Objectif :** garder un état avec une variable `total`.
#
# Complétez le programme :
#
# - le choix `1` ajoute 5 au total ;
# - le choix `2` ajoute 10 au total ;
# - le choix `3` affiche le total actuel ;
# - le choix `q` quitte le programme ;
# - les autres choix affichent un message d'erreur.

# %% [markdown]
# # 5. Mini-projet final : quiz interactif

# %% [markdown]
# ## Exercice 12 — 30 à 40 min
#
# **Objectif :** construire un programme interactif complet avec conditions, boucles et suivi d'un score.
#
# Vous allez créer un quiz interactif.
#
# Le programme pose plusieurs questions à l'utilisateur. Pour chaque réponse, il indique si la réponse est correcte et met à jour un score.
#
# À la fin, il affiche le score final.

# %% [markdown]
# ## Fonctionnalités minimales
#
# Votre programme doit :
#
# - poser au moins 4 questions ;
# - utiliser une boucle ;
# - utiliser au moins un `if` / `else` ;
# - garder un score ;
# - afficher le score final ;
# - permettre à l'utilisateur d'arrêter en tapant `stop` avant de répondre à une question.
#
# Important : n'utilisez pas de fonctions dans cette séance.

# %% [markdown]
# ## Données de départ possibles
#
# Vous pouvez utiliser deux listes : une liste de questions et une liste de réponses.
#
# Les réponses peuvent être courtes pour faciliter la comparaison.

# %%
questions = [
    "Combien font 2 + 3 ? ",
    "Quel mot-clé permet de tester une condition en Python ? ",
    "Combien y a-t-il de valeurs booléennes possibles ? ",
    "Quel mot permet de répéter tant qu'une condition est vraie ? "
]

reponses = ["5", "if", "2", "while"]

# %% [markdown]
# ## Pour aller plus loin
#
# Ajoutez une ou plusieurs extensions :
#
# - afficher un message différent selon le score final ;
# - accepter les réponses en majuscules ou minuscules ;
# - compter le nombre de questions réellement répondues ;
# - donner une seconde tentative en cas de mauvaise réponse ;
# - afficher la bonne réponse quand l'utilisateur se trompe.

# %% [markdown]
# <details>
# <summary>Indice 1</summary>
#
# Commencez avec `score = 0`, puis parcourez les indices des questions avec `range(len(questions))`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Indice 2</summary>
#
# Pour comparer la réponse donnée à la bonne réponse, utilisez la même position dans les deux listes.
#
# Exemple : `questions[0]` va avec `reponses[0]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Indice 3</summary>
#
# Pour arrêter avant la fin, vous pouvez tester si la réponse vaut `stop`, puis utiliser `break`.
#
# </details>

# %% [markdown]
# # Récapitulatif

# %% [markdown]
# ## Choisir entre `if`, `for` et `while`
#
# - Utilisez `if` quand le programme doit choisir selon une condition.
# - Utilisez `for` quand vous voulez parcourir une collection ou répéter un nombre connu de fois.
# - Utilisez `while` quand vous voulez répéter jusqu'à ce qu'une condition change.
#
# ## Trois erreurs fréquentes à retenir
#
# - Oublier les deux-points `:` après `if`, `elif`, `else`, `for` ou `while`.
# - Confondre `=` et `==`.
# - Oublier de modifier une variable dans une boucle `while`, ce qui peut créer une boucle infinie.

# %% [markdown]
# # Corrigé — à ne pas montrer immédiatement
#
# > Note enseignant : les solutions ci-dessous privilégient la lisibilité. Certaines questions acceptent d'autres réponses correctes.

# %% [markdown]
# ## Correction de l'échauffement

# %%
temperature = 28

if temperature > 25:
    print("Il fait chaud")

# %% [markdown]
# Il manquait les deux-points après la condition.

# %% [markdown]
# ## Correction de l'activité sur la livraison

# %%
montant = 42
client_fidele = False

if montant >= 50 or client_fidele:
    print("Livraison gratuite")
else:
    print("Livraison payante")

# %% [markdown]
# Le montant est inférieur à 50 et le client n'est pas fidèle. Les deux parties du `or` sont donc fausses.

# %% [markdown]
# ## Correction du débogage sur le mot de passe

# %%
mot_de_passe = "python123"

if mot_de_passe == "python123":
    print("Connexion réussie")
else:
    print("Mot de passe incorrect")

# %% [markdown]
# `==` teste une égalité. `=` sert à affecter une valeur.

# %% [markdown]
# ## Correction de l'exercice 1

# %%
age = int(input("Quel est votre âge ? "))

if age >= 18:
    print("Vous pouvez voter")
else:
    print("Vous ne pouvez pas encore voter")

# %% [markdown]
# ## Correction de l'exercice 2

# %%
temperature = float(input("Température en °C : "))

if temperature < 0:
    print("Risque de gel")
elif temperature <= 25:
    print("Température normale")
else:
    print("Il fait chaud")

# %% [markdown]
# ## Correction de l'exercice 3

# %%
age = int(input("Âge : "))

if age < 18 or age > 65:
    print("Tarif réduit")
else:
    print("Tarif normal")

# %% [markdown]
# ## Correction de l'exercice 4

# %%
montant = float(input("Montant du panier : "))
distance = float(input("Distance en km : "))

if montant >= 50:
    frais = 0
elif distance <= 5:
    frais = 3
else:
    frais = 6

print("Frais de livraison :", frais, "euros")

# %% [markdown]
# ## Correction du débogage sur le panier

# %%
panier = [4, 7, 3]
total = 0

for prix in panier:
    total = total + prix

print(total)

# %% [markdown]
# Il manquait les deux-points après `for`, et la ligne de calcul devait être indentée.

# %% [markdown]
# ## Correction de l'exercice 5

# %%
prenoms = ["Lina", "Nora", "Adam", "Yanis"]

for prenom in prenoms:
    print("Bonjour", prenom)

# %% [markdown]
# ## Correction de l'exercice 6

# %%
notes = [8, 12, 15, 6, 10, 19, 9]
compteur = 0

for note in notes:
    if note >= 10:
        compteur = compteur + 1

print("Nombre de notes validées :", compteur)

# %% [markdown]
# ## Correction de l'exercice 7

# %%
prix = [4, 12, 9, 25, 3, 16]
total = 0

for prix_article in prix:
    if prix_article >= 10:
        total = total + prix_article

print("Total :", total)

# %% [markdown]
# ## Correction de l'exercice 8

# %%
temperatures = [22, 28, 31, 35, 29, 24, 30]
jours_alerte = 0

for temperature in temperatures:
    if temperature >= 30:
        print(temperature, "Alerte")
        jours_alerte = jours_alerte + 1
    else:
        print(temperature)

print("Nombre de jours en alerte :", jours_alerte)

# %% [markdown]
# ## Correction de la boucle infinie

# %%
compteur = 1

while compteur <= 5:
    print(compteur)
    compteur = compteur + 1

# %% [markdown]
# La variable `compteur` doit changer dans la boucle pour que la condition finisse par devenir fausse.

# %% [markdown]
# ## Correction de l'exercice 9

# %%
mot_de_passe = input("Mot de passe : ")

while mot_de_passe != "python":
    mot_de_passe = input("Mot de passe incorrect. Réessayez : ")

print("Bienvenue")

# %% [markdown]
# ## Correction de l'exercice 10

# %%
compteur = 10

while compteur >= 1:
    print(compteur)
    compteur = compteur - 1

print("Décollage")

# %% [markdown]
# ## Correction de l'exercice 11

# %%
total = 0
saisie = input("Nombre ou stop : ")

while saisie != "stop":
    nombre = int(saisie)
    total = total + nombre
    saisie = input("Nombre ou stop : ")

print("Total :", total)

# %% [markdown]
# ## Correction du défi guidé, étape 1

# %%
print("1 - Ajouter 5 euros")
print("2 - Ajouter 10 euros")
print("3 - Afficher le total")
print("q - Quitter")

choix = input("Votre choix : ")
print("Choix saisi :", choix)

# %% [markdown]
# ## Correction du défi guidé, étape 2

# %%
print("1 - Ajouter 5 euros")
print("2 - Ajouter 10 euros")
print("3 - Afficher le total")
print("q - Quitter")

choix = input("Votre choix : ")

if choix == "1":
    print("Ajout de 5 euros")
elif choix == "2":
    print("Ajout de 10 euros")
elif choix == "3":
    print("Affichage du total")
else:
    print("Choix inconnu")

# %% [markdown]
# ## Correction du défi guidé, étape 3

# %%
choix = ""

while choix != "q":
    print("1 - Ajouter 5 euros")
    print("2 - Ajouter 10 euros")
    print("3 - Afficher le total")
    print("q - Quitter")

    choix = input("Votre choix : ")

    if choix == "1":
        print("Ajout de 5 euros")
    elif choix == "2":
        print("Ajout de 10 euros")
    elif choix == "3":
        print("Affichage du total")
    elif choix == "q":
        print("Au revoir")
    else:
        print("Choix inconnu")

# %% [markdown]
# ## Correction du défi guidé, étape 4

# %%
total = 0
choix = ""

while choix != "q":
    print("1 - Ajouter 5 euros")
    print("2 - Ajouter 10 euros")
    print("3 - Afficher le total")
    print("q - Quitter")

    choix = input("Votre choix : ")

    if choix == "1":
        total = total + 5
        print("5 euros ajoutés")
    elif choix == "2":
        total = total + 10
        print("10 euros ajoutés")
    elif choix == "3":
        print("Total actuel :", total, "euros")
    elif choix == "q":
        print("Total final :", total, "euros")
    else:
        print("Choix inconnu")

# %% [markdown]
# ## Correction de l'exercice 12

# %%
questions = [
    "Combien font 2 + 3 ? ",
    "Quel mot-clé permet de tester une condition en Python ? ",
    "Combien y a-t-il de valeurs booléennes possibles ? ",
    "Quel mot permet de répéter tant qu'une condition est vraie ? "
]

reponses = ["5", "if", "2", "while"]

score = 0
questions_repondues = 0

for indice in range(len(questions)):
    saisie = input(questions[indice])

    if saisie == "stop":
        break

    questions_repondues = questions_repondues + 1

    if saisie == reponses[indice]:
        print("Bonne réponse")
        score = score + 1
    else:
        print("Mauvaise réponse")

print("Score final :", score, "/", questions_repondues)

# %% [markdown]
# ## Variante possible du mini-projet avec une extension

# %%
questions = [
    "Combien font 2 + 3 ? ",
    "Quel mot-clé permet de tester une condition en Python ? ",
    "Combien y a-t-il de valeurs booléennes possibles ? ",
    "Quel mot permet de répéter tant qu'une condition est vraie ? "
]

reponses = ["5", "if", "2", "while"]

score = 0
questions_repondues = 0

for indice in range(len(questions)):
    saisie = input(questions[indice])
    saisie = saisie.lower()

    if saisie == "stop":
        break

    questions_repondues = questions_repondues + 1

    if saisie == reponses[indice]:
        print("Bonne réponse")
        score = score + 1
    else:
        print("Mauvaise réponse. La bonne réponse était :", reponses[indice])

print("Score final :", score, "/", questions_repondues)

if questions_repondues == 0:
    print("Aucune question répondue")
elif score == questions_repondues:
    print("Excellent résultat")
elif score >= questions_repondues / 2:
    print("Bon début")
else:
    print("À retravailler tranquillement")
